# %%
import numpy as np
import matplotlib.pyplot as plt

# Sampling parameters
Fs = 1000  # Sampling frequency (Hz)
T = 1 / Fs  # Sampling period
t = np.linspace(0, 1, Fs, endpoint=False)  # Time vector

# Generate a signal with two frequency components (70Hz, 90Hz)
f1, f2 = 70, 90
signal = np.sin(2 * np.pi * f1 * t) + 0.5 * np.sin(2 * np.pi * f2 * t)

# Plot time-domain signal
plt.figure(figsize=(8, 4))
plt.plot(t, signal)
plt.title("Time Domain Signal")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid()
plt.show()

# %%
# Compute FFT (Fast Fourier Transform)
X = np.fft.fft(signal)
freqs = np.fft.fftfreq(len(X), T)  # Frequency axis
X_magnitude = np.abs(X) / len(X)  # Normalize magnitude

# Plot the frequency spectrum (only positive frequencies)
plt.figure(figsize=(8, 4))
plt.plot(freqs[:Fs//2], X_magnitude[:Fs//2])  # Single-sided spectrum
plt.title("Frequency Spectrum (FFT)")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid()
plt.show()
